# %% [markdown]
# ## CREST XD DATA CLEANING

# %%
#required libraries
import os #for reading files
import pandas as pd #for data manipulation (cleaning the dataset,checking for nulls,dropping nulls, checking for duplicates etc)
import re #regular expressions, which allow you to search, match, and manipulate text by defining patterns.
from textblob import TextBlob #A sentiment analysis package
from nltk.sentiment.vader import SentimentIntensityAnalyzer #Another sentiment analysis tool
import nltk #For the sentiment analysis

# %%
# Download the VADER lexicon
nltk.download('vader_lexicon') #a pre-trained model for sentiment analysis.NB: It takes into consideration the emojis in the text 
#and 1=positive,0=Neutral,-1=Negative
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Olaniyi
# [nltk_data]     David\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#The directory where my csv file is stored
os.chdir(r"c:\\Users\\Olaniyi David\\Desktop")

# %%
#reading the csv file using pandas
data = pd.read_csv("web3_tweets.csv")

# %%
#Displaying the first five columns in the dataset
data.head()
# Out:
#    Tweet_count           Username  \
# 0            1  JackTheRippler ©️
# 1            2     Patrick 🔺️9000
# 2            3               BeL2
# 3            4        🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 4            5  🔮Metaverse Worlds
#
#                                                 Text  \
# 0  🚨PAY ATTENTION! A VIDEO REEMERGES OF GARY GENS...
# 1  Flash Giveaway 🚨🚨\n\nGiving 3 WL spots to next...
# 2  Bitcoin is the cornerstone of the next financi...
# 3  🎮 Exciting news! @RavegameNFT has teamed up wi...
# 4  🎯 @KingdomXGame is excited to announce its par...
#
#                        Created_At  Retweets  Likes   Views
# 0  Thu Oct 24 08:57:45 +0000 2024         1      8   224.0
# 1  Thu Oct 24 08:33:04 +0000 2024        16     18   238.0
# 2  Thu Oct 24 07:03:04 +0000 2024         7     21   293.0
# 3  Tue Oct 22 14:35:17 +0000 2024        48     76  2755.0
# 4  Tue Oct 22 13:23:17 +0000 2024        43     71  6674.0

# %%
#Numbr of rows and columns contained in the dataset 
data.shape
# Out:
# (3462, 7)

# %%
#Checking for null values in each column
data.isnull().sum()
# Out:
# Tweet_count     0
# Username        0
# Text            0
# Created_At      0
# Retweets        0
# Likes           0
# Views          15
# dtype: int64

# %% [markdown]
# ## Creating new attributes
#
# 1. Retention rate = The sum of the retweets and likes divided by the total numbr of views. NB: 0 = bad retention, 2=Excellent retention
# 2. Total Number of engagments
# 3. From the the created_at column, these columns were created (Day, Hour and Time of the day(Morning, evening,afternoon etc)
# 4. Keyword columnn was created by mapping each tweet to the respective keywords used in scraping them
# 5. Two extra columns which contained the sentiment analysis results for two different models (Textblob and Vader)

# %%
data['retention_rate'] = (data['Retweets'] + data['Likes']) / data['Views']

# %%
data['total_engagements'] = data['Retweets'] + data['Likes']

# %%
# Extract the day abbreviation (first 3 characters)
data['day'] = data['Created_At'].str[:3]

# Mapping of day abbreviations to full weekday names
day_map = {
    'Mon': 'Monday',
    'Tue': 'Tuesday',
    'Wed': 'Wednesday',
    'Thu': 'Thursday',
    'Fri': 'Friday',
    'Sat': 'Saturday',
    'Sun': 'Sunday'
}

# Map the abbreviations to full weekday names
data['day'] = data['day'].map(day_map)

# %%
# Extract the time portion (using split to get the part with the hour)
data['hour'] = data['Created_At'].str.split(' ').str[3]

# Extract the hour from the time string
data['hour'] = data['hour'].str.split(':').str[0].astype(int)

# %%
# Define a function to categorize the time of day
def categorize_time_of_day(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

# Apply the function to create a new column with the time of day
data['time_of_day'] = data['hour'].apply(categorize_time_of_day)

# %% [markdown]
# ## Text preprocessing before extracting keywords

# %%
#convert all text to lowercase
data['Text'] = data['Text'].str.lower()

# %%
#replace the\n in all text with''(an empty string)
data['Text'] = data['Text'].str.replace('\n', ' ')

# %%
#Removed the hashtag, @ symbol and links to elimante noise and to avoid confusing the model
def clean_tweet(text):
    text = text.str.replace(r'@\w+', '', regex=True)  # Remove @mentions
    text = text.str.replace(r'#\w+', '', regex=True)  # Remove hashtags
    text = text.str.replace(r'http\S+|www\S+|https\S+', '', regex=True)  # Remove URLs
    
    return text

# Apply the function to the 'tweet' column
data['Text'] = clean_tweet(data['Text'])

# %%
#List of all the keywords and extracting them to create a new column
keywords = ["defi", "nfts", "daos", "metaverse", "layer 2", "gaming", 
    "bridges", "p2e", "wallets", "staking", "liquidity", 
    "airdrops", "stablecoins", "assets", "guilds", "shilling", 
    "farming", "socialfi", "tokenomics", "interoperability","pos","proof of stake"]

# Create a regex pattern for whole words, case-insensitive
pattern = '|'.join(rf'\b{re.escape(kw)}\b' for kw in keywords)

# Create a new column to show the keywords found
data['keyword'] = data['Text'].str.findall(pattern, flags=re.IGNORECASE).apply(lambda x: ', '.join(set(x)))

# %%
#It was observed that some rows contained empty strings so i replaced them with NA which is easier to work with
data['keyword'] = data['keyword'].replace('', pd.NA)

# %%
data['keyword'] = data['keyword'].replace(pd.NA,"general")

# %%
#defining the function that carries out the sentiment analysis
def get_sentiment_textblob(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity
def get_sentiment_vader(text):
    sid = SentimentIntensityAnalyzer()
    score = sid.polarity_scores(text)
    return score['compound']

# %%
# Using TextBlob
data['sentiment_textblob'] = data['Text'].apply(get_sentiment_textblob)

# Using VADER
data['sentiment_vader'] = data['Text'].apply(get_sentiment_vader)

# %%
data.head(50)
# Out:
#     Tweet_count                                Username  \
# 0             1                       JackTheRippler ©️
# 1             2                          Patrick 🔺️9000
# 2             3                                    BeL2
# 3             4                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 4             5                       🔮Metaverse Worlds
# 5             6                              XPLA (ⓧ.ⓧ)
# 6             7                       🔮Metaverse Worlds
# 7             8                             DeFi Tycoon
# 8             9                       🔮Metaverse Worlds
# 9            10                                Hanzo ㊗️
# 10           11                       🔮Metaverse Worlds
# 11           12                       🔮Metaverse Worlds
# 12           13                       🔮Metaverse Worlds
# 13           14                                  Royale
# 14           15                       🔮Metaverse Worlds
# 15           16                       🔮Metaverse Worlds
# 16           17       🇺🇦 CryptoDep #StandWithUkraine 🇺🇦
# 17           18                           Chainberas⛓️🐻
# 18           19                           DEFI_EAGLE 
# 19           20                       🔮Metaverse Worlds
# 20           21                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 21           22                            HealthyDegen
# 22           23                           🥖Tokenicer✲⥃⬢
# 23           24                              🏆 𝐍𝐄𝐖𝐒𝐋𝐄𝐀𝐃
# 24           25                         Adventure Layer
# 25           26                                 Avantis
# 26           27                            Hemi Network
# 27           28                       🔮Metaverse Worlds
# 28           29                             Beethoven X
# 29           30                             Dapp Centre
# 30           31                            Phantom_Defi
# 31           32                       🔮Metaverse Worlds
# 32           33                         Our Crypto Talk
# 33           34                       🔮Metaverse Worlds
# 34           35                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 35           36                         Our Crypto Talk
# 36           37                       𝐒𝐎𝐋𝐀𝐍𝐀 𝐔𝐍𝐈𝐕𝐄𝐑𝐒𝐄 🧬
# 37           38                           DEFI_EAGLE 
# 38           39                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 39           40                       🟣 𝐏𝐨𝐥𝐲𝐠𝐨𝐧 𝐒𝐩𝐚𝐜𝐞 🟣
# 40           41                       🔮Metaverse Worlds
# 41           42                         𝐅𝐀𝐍𝐓𝐎𝐌 𝐔𝐍𝐈𝐕𝐄𝐑𝐒𝐄
# 42           43                       🟣 𝐏𝐨𝐥𝐲𝐠𝐨𝐧 𝐒𝐩𝐚𝐜𝐞 🟣
# 43           44                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 44           45                      Bonzo Finance Labs
# 45           46                                  Kondux
# 46           47                             KingWilliam
# 47           48  ᴛʜᴇ ʙʟᴏᴄᴋ ʀᴜɴɴᴇʀ Podcast | 91.bitmap 🟧
# 48           49                         Our Crypto Talk
# 49           50                                Hanzo ㊗️
#
#                                                  Text  \
# 0   🚨pay attention! a video reemerges of gary gens...
# 1   flash giveaway 🚨🚨  giving 3 wl spots to next m...
# 2   bitcoin is the cornerstone of the next financi...
# 3   🎮 exciting news!  has teamed up with  to bring...
# 4   🎯  is excited to announce its partnership with...
# 5   🥇introducing the 1st palympic!🥇  how to partic...
# 6   🎮  partners with  to offer exclusive rewards t...
# 7   exciting news!  is launching a mine to earn $m...
# 8   🔮  daily digest 10/22/2024  🔮  partnership wit...
# 9   to make $1m, you need one 1000x token.  and ev...
# 10  ✨  partners with  , a decentralized rpc provid...
# 11  🌐 as the  evolves, seamless movement between p...
# 12  ♦️  joined forces with  to revolutionize globa...
# 13  new thread🧵 project: offthegrid    off the gri...
# 14  🛞  announces its partnership with   🤝 this col...
# 15  ✨  has partnered with   🤝 this collaboration a...
# 16  ⚡️  $om kicks off its mainnet to bringing real...
# 17  🚨 mint info ⛓️🐻    supply: 3,333 nfts   date: ...
# 18  ✨  has teamed up with  and  to boost liquidity...
# 19  🖲️  has announced its partnership with   to en...
# 20  🔫  just leveled up by integrating with !     🧟...
# 21  one of my friends i just onboarded to  just go...
# 22  theres rising concern that many of the project...
# 23  ✨  has reached a partnership with .  🐐  is the...
# 24  [how adventure layer achieves true gaming scal...
# 25  introducing our new look and mission, guided b...
# 26  hemi is collaborating with — the first bitcoin...
# 27  🎲  announces its partnership with   🐍  has evo...
# 28  choose your fighter.  standard $ftm, or...  $f...
# 29  the wait is over, $red main sale is now live! ...
# 30  🪂 metamask has officially confirmed an airdrop...
# 31  ☄️ has partnered with  to integrate social net...
# 32  ⚠️ top  for the bull run 🌍  sorted by market c...
# 33  🛟  has teamed up with   💥  is the first nft om...
# 34  🛠️ effortless token management, maximum impact...
# 35  top  for    🤑💰  sorted by market cap 👇  $kas (...
# 36  💥  collaborates with  to enhance security on  ...
# 37  🌙 's web3 name sdk is being integrated by .  👨...
# 38  🚀 big things are happening!  teams up with   t...
# 39  ⚡️ understanding 's hybrid consensus mechanism...
# 40  🎮  has announced its partnership with , an act...
# 41  🚀 just in:  partners with  network to bring re...
# 42  🎯  is joining forces with  to enhance tradfi/d...
# 43  🏹 exciting news from ! they’ve just teamed up ...
# 44  bonzo finance is going live on october 28! 🌐  ...
# 45  the future of creative environments is here.  ...
# 46  found 2 insider wallets and made $40,000 thank...
# 47  the bitmap studios are set to release a truly ...
# 48  top  for the bull run 🌍  sorted by fdv 👇  $tia...
# 49  every time you swap $100, you lose $0.8  at th...
#
#                         Created_At  Retweets  Likes     Views  retention_rate  \
# 0   Thu Oct 24 08:57:45 +0000 2024         1      8     224.0        0.040179
# 1   Thu Oct 24 08:33:04 +0000 2024        16     18     238.0        0.142857
# 2   Thu Oct 24 07:03:04 +0000 2024         7     21     293.0        0.095563
# 3   Tue Oct 22 14:35:17 +0000 2024        48     76    2755.0        0.045009
# 4   Tue Oct 22 13:23:17 +0000 2024        43     71    6674.0        0.017081
# 5   Thu Oct 24 07:47:11 +0000 2024         2     10     361.0        0.033241
# 6   Wed Oct 23 17:39:10 +0000 2024        52     75    6447.0        0.019699
# 7   Thu Oct 24 07:46:38 +0000 2024         7     22     244.0        0.118852
# 8   Wed Oct 23 09:31:00 +0000 2024        49     74   17496.0        0.007030
# 9   Sat Oct 19 17:44:46 +0000 2024       322   1775  334820.0        0.006263
# 10  Wed Oct 23 14:08:59 +0000 2024        45     68    9139.0        0.012365
# 11  Fri Oct 18 12:40:42 +0000 2024        55     80   11413.0        0.011829
# 12  Tue Oct 15 20:32:59 +0000 2024        38     54    7626.0        0.012064
# 13  Tue Oct 22 12:37:24 +0000 2024        90     94    5073.0        0.036270
# 14  Mon Oct 21 21:34:10 +0000 2024        41     81    4877.0        0.025015
# 15  Mon Oct 21 22:20:11 +0000 2024        43     88    6013.0        0.021786
# 16  Thu Oct 24 08:44:23 +0000 2024         1      5     363.0        0.016529
# 17  Tue Oct 22 19:54:35 +0000 2024      1071   3059   66912.0        0.061723
# 18  Wed Oct 23 12:28:06 +0000 2024        45     70   11511.0        0.009990
# 19  Fri Oct 18 12:57:38 +0000 2024        50     85    5558.0        0.024289
# 20  Mon Oct 21 21:56:03 +0000 2024        62     85   16301.0        0.009018
# 21  Thu Oct 24 04:17:41 +0000 2024         7     88    8418.0        0.011285
# 22  Thu Apr 25 05:56:37 +0000 2024        54    207   14347.0        0.018192
# 23  Mon Oct 21 08:30:58 +0000 2024        58     92    4300.0        0.034884
# 24  Thu Oct 24 02:24:21 +0000 2024         2      5     182.0        0.038462
# 25  Wed Oct 16 14:23:53 +0000 2024        21     83   28098.0        0.003701
# 26  Wed Oct 23 18:00:06 +0000 2024      1690   1188    7629.0        0.377245
# 27  Wed Oct 23 13:36:03 +0000 2024        37     59    4376.0        0.021938
# 28  Thu Oct 24 08:23:14 +0000 2024         7     13     637.0        0.031397
# 29  Wed Oct 23 11:47:13 +0000 2024       381   1340  155596.0        0.011061
# 30  Mon Oct 21 16:25:16 +0000 2024       110    369  104621.0        0.004578
# 31  Tue Oct 22 20:16:48 +0000 2024        36     71    5597.0        0.019117
# 32  Thu Feb 22 16:46:08 +0000 2024       144    495   66384.0        0.009626
# 33  Tue Oct 15 21:52:53 +0000 2024        37     51    6714.0        0.013107
# 34  Tue Oct 15 21:53:21 +0000 2024        43     64    9009.0        0.011877
# 35  Thu Feb 29 16:38:42 +0000 2024       108    486   83642.0        0.007102
# 36  Thu Oct 17 21:10:46 +0000 2024        61     99    2074.0        0.077146
# 37  Fri Oct 18 10:02:38 +0000 2024        46     81    7295.0        0.017409
# 38  Wed Oct 16 22:05:09 +0000 2024        47     56    4690.0        0.021962
# 39  Fri Oct 18 13:15:34 +0000 2024        58     92   11994.0        0.012506
# 40  Fri Oct 18 11:23:32 +0000 2024        46     75    6688.0        0.018092
# 41  Mon Oct 21 11:05:36 +0000 2024        72    126    8125.0        0.024369
# 42  Wed Oct 23 14:11:11 +0000 2024        49     73    8937.0        0.013651
# 43  Wed Oct 16 22:18:03 +0000 2024        41     53    2183.0        0.043060
# 44  Wed Oct 23 15:46:01 +0000 2024        67    170    6478.0        0.036585
# 45  Thu Oct 17 17:33:39 +0000 2024        48    155   13716.0        0.014800
# 46  Tue Oct 22 18:45:12 +0000 2024        31    152   31212.0        0.005863
# 47  Tue Oct 22 00:57:32 +0000 2024        41     94    7439.0        0.018148
# 48  Fri Mar 08 12:32:23 +0000 2024       127    450   75625.0        0.007630
# 49  Tue Oct 22 19:00:56 +0000 2024       105    577  137083.0        0.004975
#
#     total_engagements        day  hour time_of_day  \
# 0                   9   Thursday     8     Morning
# 1                  34   Thursday     8     Morning
# 2                  28   Thursday     7     Morning
# 3                 124    Tuesday    14   Afternoon
# 4                 114    Tuesday    13   Afternoon
# 5                  12   Thursday     7     Morning
# 6                 127  Wednesday    17     Evening
# 7                  29   Thursday     7     Morning
# 8                 123  Wednesday     9     Morning
# 9                2097   Saturday    17     Evening
# 10                113  Wednesday    14   Afternoon
# 11                135     Friday    12   Afternoon
# 12                 92    Tuesday    20     Evening
# 13                184    Tuesday    12   Afternoon
# 14                122     Monday    21       Night
# 15                131     Monday    22       Night
# 16                  6   Thursday     8     Morning
# 17               4130    Tuesday    19     Evening
# 18                115  Wednesday    12   Afternoon
# 19                135     Friday    12   Afternoon
# 20                147     Monday    21       Night
# 21                 95   Thursday     4       Night
# 22                261   Thursday     5     Morning
# 23                150     Monday     8     Morning
# 24                  7   Thursday     2       Night
# 25                104  Wednesday    14   Afternoon
# 26               2878  Wednesday    18     Evening
# 27                 96  Wednesday    13   Afternoon
# 28                 20   Thursday     8     Morning
# 29               1721  Wednesday    11     Morning
# 30                479     Monday    16   Afternoon
# 31                107    Tuesday    20     Evening
# 32                639   Thursday    16   Afternoon
# 33                 88    Tuesday    21       Night
# 34                107    Tuesday    21       Night
# 35                594   Thursday    16   Afternoon
# 36                160   Thursday    21       Night
# 37                127     Friday    10     Morning
# 38                103  Wednesday    22       Night
# 39                150     Friday    13   Afternoon
# 40                121     Friday    11     Morning
# 41                198     Monday    11     Morning
# 42                122  Wednesday    14   Afternoon
# 43                 94  Wednesday    22       Night
# 44                237  Wednesday    15   Afternoon
# 45                203   Thursday    17     Evening
# 46                183    Tuesday    18     Evening
# 47                135    Tuesday     0       Night
# 48                577     Friday    12   Afternoon
# 49                682    Tuesday    19     Evening
#
#                         keyword  sentiment_textblob  sentiment_vader
# 0               defi, liquidity            0.241364           0.6562
# 1                       general            0.000000           0.7906
# 2                       general            0.081169           0.5574
# 3                     metaverse            0.092969           0.6219
# 4                       layer 2            0.187500           0.7717
# 5                          nfts            0.350000           0.8715
# 6                        gaming            0.600000           0.7506
# 7                       staking            0.375000           0.9080
# 8                       layer 2            0.000000           0.4215
# 9                     liquidity            0.250000           0.0000
# 10                    liquidity            0.000000           0.4767
# 11             interoperability            0.025000           0.8070
# 12            assets, liquidity            0.168750           0.1779
# 13                 nfts, gaming            0.242273           0.8313
# 14                       gaming            0.475000           0.7506
# 15                       gaming            0.243182           0.6124
# 16                       assets            0.000000           0.1779
# 17                nfts, wallets            0.000000           0.4738
# 18                    liquidity            0.575000           0.7845
# 19            gaming, metaverse            0.033333           0.0000
# 20                         nfts            0.226852           0.8213
# 21                 assets, nfts           -0.458333          -0.1531
# 22                      general            0.133333           0.1280
# 23                      layer 2            0.250000           0.2732
# 24                       gaming            0.205606           0.7506
# 25      assets, defi, liquidity            0.097273           0.4019
# 26            assets, liquidity            0.216667           0.5859
# 27            gaming, metaverse            0.158333           0.0772
# 28                defi, staking            0.200000           0.8625
# 29                      general            0.130492           0.2462
# 30                      general            0.227273           0.6467
# 31                 gaming, defi            0.033333           0.6369
# 32                      general            0.500000           0.2023
# 33              nfts, liquidity            0.250000           0.5423
# 34                       gaming            0.400000           0.5562
# 35                      general            0.500000           0.2023
# 36                       assets            0.193750           0.8402
# 37          assets, stablecoins            0.000000           0.7717
# 38            nfts, p2e, gaming            0.174091           0.6784
# 39          proof of stake, pos            0.333333           0.5423
# 40                       gaming            0.200000           0.7906
# 41                 gaming, defi            0.266667           0.8225
# 42       defi, interoperability            0.203571           0.5635
# 43                         nfts            0.042143           0.9196
# 44      assets, defi, liquidity            0.210227           0.8975
# 45       nfts, interoperability            0.183333           0.8720
# 46                      wallets            0.242857           0.4404
# 47  metaverse, interoperability            0.118603           0.4926
# 48                      general            0.250000           0.7430
# 49                      general            0.000000          -0.4019

# %%
#New size of the dataset after 
data.shape
# Out:
# (3462, 15)

# %%
data.isnull().sum()
# Out:
# Tweet_count            0
# Username               0
# Text                   0
# Created_At             0
# Retweets               0
# Likes                  0
# Views                 15
# retention_rate        15
# total_engagements      0
# day                    0
# hour                   0
# time_of_day            0
# keyword                0
# sentiment_textblob     0
# sentiment_vader        0
# dtype: int64

# %%
data.head(50)
# Out:
#     Tweet_count                                Username  \
# 0             1                       JackTheRippler ©️
# 1             2                          Patrick 🔺️9000
# 2             3                                    BeL2
# 3             4                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 4             5                       🔮Metaverse Worlds
# 5             6                              XPLA (ⓧ.ⓧ)
# 6             7                       🔮Metaverse Worlds
# 7             8                             DeFi Tycoon
# 8             9                       🔮Metaverse Worlds
# 9            10                                Hanzo ㊗️
# 10           11                       🔮Metaverse Worlds
# 11           12                       🔮Metaverse Worlds
# 12           13                       🔮Metaverse Worlds
# 13           14                                  Royale
# 14           15                       🔮Metaverse Worlds
# 15           16                       🔮Metaverse Worlds
# 16           17       🇺🇦 CryptoDep #StandWithUkraine 🇺🇦
# 17           18                           Chainberas⛓️🐻
# 18           19                           DEFI_EAGLE 
# 19           20                       🔮Metaverse Worlds
# 20           21                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 21           22                            HealthyDegen
# 22           23                           🥖Tokenicer✲⥃⬢
# 23           24                              🏆 𝐍𝐄𝐖𝐒𝐋𝐄𝐀𝐃
# 24           25                         Adventure Layer
# 25           26                                 Avantis
# 26           27                            Hemi Network
# 27           28                       🔮Metaverse Worlds
# 28           29                             Beethoven X
# 29           30                             Dapp Centre
# 30           31                            Phantom_Defi
# 31           32                       🔮Metaverse Worlds
# 32           33                         Our Crypto Talk
# 33           34                       🔮Metaverse Worlds
# 34           35                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 35           36                         Our Crypto Talk
# 36           37                       𝐒𝐎𝐋𝐀𝐍𝐀 𝐔𝐍𝐈𝐕𝐄𝐑𝐒𝐄 🧬
# 37           38                           DEFI_EAGLE 
# 38           39                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 39           40                       🟣 𝐏𝐨𝐥𝐲𝐠𝐨𝐧 𝐒𝐩𝐚𝐜𝐞 🟣
# 40           41                       🔮Metaverse Worlds
# 41           42                         𝐅𝐀𝐍𝐓𝐎𝐌 𝐔𝐍𝐈𝐕𝐄𝐑𝐒𝐄
# 42           43                       🟣 𝐏𝐨𝐥𝐲𝐠𝐨𝐧 𝐒𝐩𝐚𝐜𝐞 🟣
# 43           44                             🕹 𝐏𝟐𝐄_𝐒𝐏𝐀𝐂𝐄
# 44           45                      Bonzo Finance Labs
# 45           46                                  Kondux
# 46           47                             KingWilliam
# 47           48  ᴛʜᴇ ʙʟᴏᴄᴋ ʀᴜɴɴᴇʀ Podcast | 91.bitmap 🟧
# 48           49                         Our Crypto Talk
# 49           50                                Hanzo ㊗️
#
#                                                  Text  \
# 0   🚨pay attention! a video reemerges of gary gens...
# 1   flash giveaway 🚨🚨  giving 3 wl spots to next m...
# 2   bitcoin is the cornerstone of the next financi...
# 3   🎮 exciting news!  has teamed up with  to bring...
# 4   🎯  is excited to announce its partnership with...
# 5   🥇introducing the 1st palympic!🥇  how to partic...
# 6   🎮  partners with  to offer exclusive rewards t...
# 7   exciting news!  is launching a mine to earn $m...
# 8   🔮  daily digest 10/22/2024  🔮  partnership wit...
# 9   to make $1m, you need one 1000x token.  and ev...
# 10  ✨  partners with  , a decentralized rpc provid...
# 11  🌐 as the  evolves, seamless movement between p...
# 12  ♦️  joined forces with  to revolutionize globa...
# 13  new thread🧵 project: offthegrid    off the gri...
# 14  🛞  announces its partnership with   🤝 this col...
# 15  ✨  has partnered with   🤝 this collaboration a...
# 16  ⚡️  $om kicks off its mainnet to bringing real...
# 17  🚨 mint info ⛓️🐻    supply: 3,333 nfts   date: ...
# 18  ✨  has teamed up with  and  to boost liquidity...
# 19  🖲️  has announced its partnership with   to en...
# 20  🔫  just leveled up by integrating with !     🧟...
# 21  one of my friends i just onboarded to  just go...
# 22  theres rising concern that many of the project...
# 23  ✨  has reached a partnership with .  🐐  is the...
# 24  [how adventure layer achieves true gaming scal...
# 25  introducing our new look and mission, guided b...
# 26  hemi is collaborating with — the first bitcoin...
# 27  🎲  announces its partnership with   🐍  has evo...
# 28  choose your fighter.  standard $ftm, or...  $f...
# 29  the wait is over, $red main sale is now live! ...
# 30  🪂 metamask has officially confirmed an airdrop...
# 31  ☄️ has partnered with  to integrate social net...
# 32  ⚠️ top  for the bull run 🌍  sorted by market c...
# 33  🛟  has teamed up with   💥  is the first nft om...
# 34  🛠️ effortless token management, maximum impact...
# 35  top  for    🤑💰  sorted by market cap 👇  $kas (...
# 36  💥  collaborates with  to enhance security on  ...
# 37  🌙 's web3 name sdk is being integrated by .  👨...
# 38  🚀 big things are happening!  teams up with   t...
# 39  ⚡️ understanding 's hybrid consensus mechanism...
# 40  🎮  has announced its partnership with , an act...
# 41  🚀 just in:  partners with  network to bring re...
# 42  🎯  is joining forces with  to enhance tradfi/d...
# 43  🏹 exciting news from ! they’ve just teamed up ...
# 44  bonzo finance is going live on october 28! 🌐  ...
# 45  the future of creative environments is here.  ...
# 46  found 2 insider wallets and made $40,000 thank...
# 47  the bitmap studios are set to release a truly ...
# 48  top  for the bull run 🌍  sorted by fdv 👇  $tia...
# 49  every time you swap $100, you lose $0.8  at th...
#
#                         Created_At  Retweets  Likes     Views  retention_rate  \
# 0   Thu Oct 24 08:57:45 +0000 2024         1      8     224.0        0.040179
# 1   Thu Oct 24 08:33:04 +0000 2024        16     18     238.0        0.142857
# 2   Thu Oct 24 07:03:04 +0000 2024         7     21     293.0        0.095563
# 3   Tue Oct 22 14:35:17 +0000 2024        48     76    2755.0        0.045009
# 4   Tue Oct 22 13:23:17 +0000 2024        43     71    6674.0        0.017081
# 5   Thu Oct 24 07:47:11 +0000 2024         2     10     361.0        0.033241
# 6   Wed Oct 23 17:39:10 +0000 2024        52     75    6447.0        0.019699
# 7   Thu Oct 24 07:46:38 +0000 2024         7     22     244.0        0.118852
# 8   Wed Oct 23 09:31:00 +0000 2024        49     74   17496.0        0.007030
# 9   Sat Oct 19 17:44:46 +0000 2024       322   1775  334820.0        0.006263
# 10  Wed Oct 23 14:08:59 +0000 2024        45     68    9139.0        0.012365
# 11  Fri Oct 18 12:40:42 +0000 2024        55     80   11413.0        0.011829
# 12  Tue Oct 15 20:32:59 +0000 2024        38     54    7626.0        0.012064
# 13  Tue Oct 22 12:37:24 +0000 2024        90     94    5073.0        0.036270
# 14  Mon Oct 21 21:34:10 +0000 2024        41     81    4877.0        0.025015
# 15  Mon Oct 21 22:20:11 +0000 2024        43     88    6013.0        0.021786
# 16  Thu Oct 24 08:44:23 +0000 2024         1      5     363.0        0.016529
# 17  Tue Oct 22 19:54:35 +0000 2024      1071   3059   66912.0        0.061723
# 18  Wed Oct 23 12:28:06 +0000 2024        45     70   11511.0        0.009990
# 19  Fri Oct 18 12:57:38 +0000 2024        50     85    5558.0        0.024289
# 20  Mon Oct 21 21:56:03 +0000 2024        62     85   16301.0        0.009018
# 21  Thu Oct 24 04:17:41 +0000 2024         7     88    8418.0        0.011285
# 22  Thu Apr 25 05:56:37 +0000 2024        54    207   14347.0        0.018192
# 23  Mon Oct 21 08:30:58 +0000 2024        58     92    4300.0        0.034884
# 24  Thu Oct 24 02:24:21 +0000 2024         2      5     182.0        0.038462
# 25  Wed Oct 16 14:23:53 +0000 2024        21     83   28098.0        0.003701
# 26  Wed Oct 23 18:00:06 +0000 2024      1690   1188    7629.0        0.377245
# 27  Wed Oct 23 13:36:03 +0000 2024        37     59    4376.0        0.021938
# 28  Thu Oct 24 08:23:14 +0000 2024         7     13     637.0        0.031397
# 29  Wed Oct 23 11:47:13 +0000 2024       381   1340  155596.0        0.011061
# 30  Mon Oct 21 16:25:16 +0000 2024       110    369  104621.0        0.004578
# 31  Tue Oct 22 20:16:48 +0000 2024        36     71    5597.0        0.019117
# 32  Thu Feb 22 16:46:08 +0000 2024       144    495   66384.0        0.009626
# 33  Tue Oct 15 21:52:53 +0000 2024        37     51    6714.0        0.013107
# 34  Tue Oct 15 21:53:21 +0000 2024        43     64    9009.0        0.011877
# 35  Thu Feb 29 16:38:42 +0000 2024       108    486   83642.0        0.007102
# 36  Thu Oct 17 21:10:46 +0000 2024        61     99    2074.0        0.077146
# 37  Fri Oct 18 10:02:38 +0000 2024        46     81    7295.0        0.017409
# 38  Wed Oct 16 22:05:09 +0000 2024        47     56    4690.0        0.021962
# 39  Fri Oct 18 13:15:34 +0000 2024        58     92   11994.0        0.012506
# 40  Fri Oct 18 11:23:32 +0000 2024        46     75    6688.0        0.018092
# 41  Mon Oct 21 11:05:36 +0000 2024        72    126    8125.0        0.024369
# 42  Wed Oct 23 14:11:11 +0000 2024        49     73    8937.0        0.013651
# 43  Wed Oct 16 22:18:03 +0000 2024        41     53    2183.0        0.043060
# 44  Wed Oct 23 15:46:01 +0000 2024        67    170    6478.0        0.036585
# 45  Thu Oct 17 17:33:39 +0000 2024        48    155   13716.0        0.014800
# 46  Tue Oct 22 18:45:12 +0000 2024        31    152   31212.0        0.005863
# 47  Tue Oct 22 00:57:32 +0000 2024        41     94    7439.0        0.018148
# 48  Fri Mar 08 12:32:23 +0000 2024       127    450   75625.0        0.007630
# 49  Tue Oct 22 19:00:56 +0000 2024       105    577  137083.0        0.004975
#
#     total_engagements        day  hour time_of_day  \
# 0                   9   Thursday     8     Morning
# 1                  34   Thursday     8     Morning
# 2                  28   Thursday     7     Morning
# 3                 124    Tuesday    14   Afternoon
# 4                 114    Tuesday    13   Afternoon
# 5                  12   Thursday     7     Morning
# 6                 127  Wednesday    17     Evening
# 7                  29   Thursday     7     Morning
# 8                 123  Wednesday     9     Morning
# 9                2097   Saturday    17     Evening
# 10                113  Wednesday    14   Afternoon
# 11                135     Friday    12   Afternoon
# 12                 92    Tuesday    20     Evening
# 13                184    Tuesday    12   Afternoon
# 14                122     Monday    21       Night
# 15                131     Monday    22       Night
# 16                  6   Thursday     8     Morning
# 17               4130    Tuesday    19     Evening
# 18                115  Wednesday    12   Afternoon
# 19                135     Friday    12   Afternoon
# 20                147     Monday    21       Night
# 21                 95   Thursday     4       Night
# 22                261   Thursday     5     Morning
# 23                150     Monday     8     Morning
# 24                  7   Thursday     2       Night
# 25                104  Wednesday    14   Afternoon
# 26               2878  Wednesday    18     Evening
# 27                 96  Wednesday    13   Afternoon
# 28                 20   Thursday     8     Morning
# 29               1721  Wednesday    11     Morning
# 30                479     Monday    16   Afternoon
# 31                107    Tuesday    20     Evening
# 32                639   Thursday    16   Afternoon
# 33                 88    Tuesday    21       Night
# 34                107    Tuesday    21       Night
# 35                594   Thursday    16   Afternoon
# 36                160   Thursday    21       Night
# 37                127     Friday    10     Morning
# 38                103  Wednesday    22       Night
# 39                150     Friday    13   Afternoon
# 40                121     Friday    11     Morning
# 41                198     Monday    11     Morning
# 42                122  Wednesday    14   Afternoon
# 43                 94  Wednesday    22       Night
# 44                237  Wednesday    15   Afternoon
# 45                203   Thursday    17     Evening
# 46                183    Tuesday    18     Evening
# 47                135    Tuesday     0       Night
# 48                577     Friday    12   Afternoon
# 49                682    Tuesday    19     Evening
#
#                         keyword  sentiment_textblob  sentiment_vader
# 0               liquidity, defi            0.241364           0.6562
# 1                       general            0.000000           0.7906
# 2                       general            0.081169           0.5574
# 3                     metaverse            0.092969           0.6219
# 4                       layer 2            0.187500           0.7717
# 5                          nfts            0.350000           0.8715
# 6                        gaming            0.600000           0.7506
# 7                       staking            0.375000           0.9080
# 8                       layer 2            0.000000           0.4215
# 9                     liquidity            0.250000           0.0000
# 10                    liquidity            0.000000           0.4767
# 11             interoperability            0.025000           0.8070
# 12            liquidity, assets            0.168750           0.1779
# 13                 gaming, nfts            0.242273           0.8313
# 14                       gaming            0.475000           0.7506
# 15                       gaming            0.243182           0.6124
# 16                       assets            0.000000           0.1779
# 17                nfts, wallets            0.000000           0.4738
# 18                    liquidity            0.575000           0.7845
# 19            metaverse, gaming            0.033333           0.0000
# 20                         nfts            0.226852           0.8213
# 21                 assets, nfts           -0.458333          -0.1531
# 22                      general            0.133333           0.1280
# 23                      layer 2            0.250000           0.2732
# 24                       gaming            0.205606           0.7506
# 25      liquidity, assets, defi            0.097273           0.4019
# 26            liquidity, assets            0.216667           0.5859
# 27            metaverse, gaming            0.158333           0.0772
# 28                staking, defi            0.200000           0.8625
# 29                      general            0.130492           0.2462
# 30                      general            0.227273           0.6467
# 31                 gaming, defi            0.033333           0.6369
# 32                      general            0.500000           0.2023
# 33              liquidity, nfts            0.250000           0.5423
# 34                       gaming            0.400000           0.5562
# 35                      general            0.500000           0.2023
# 36                       assets            0.193750           0.8402
# 37          assets, stablecoins            0.000000           0.7717
# 38            p2e, gaming, nfts            0.174091           0.6784
# 39          proof of stake, pos            0.333333           0.5423
# 40                       gaming            0.200000           0.7906
# 41                 gaming, defi            0.266667           0.8225
# 42       defi, interoperability            0.203571           0.5635
# 43                         nfts            0.042143           0.9196
# 44      liquidity, assets, defi            0.210227           0.8975
# 45       interoperability, nfts            0.183333           0.8720
# 46                      wallets            0.242857           0.4404
# 47  metaverse, interoperability            0.118603           0.4926
# 48                      general            0.250000           0.7430
# 49                      general            0.000000          -0.4019

# %%
data.dtypes
# Out:
# Tweet_count                         int64
# Username                           object
# Text                               object
# Created_At                         object
# Retweets                            int64
# Likes                               int64
# Views                             float64
# retention_rate                    float64
# total_engagements                   int64
# keyword                            object
# sentiment_textblob                float64
# sentiment_vader                   float64
# datetime              datetime64[ns, UTC]
# dtype: object

# %%
data.loc[2196, 'Text']
# Out:
# '👂 hear from  , the co-founder of , on the real challenges of bringing  and  together in a world led by tech giants like  &amp; ! 🚀  🔥catch the full interview here  '

# %% [markdown]
# ## Twitter Script

# %%
import asyncio
import csv
import os
import random
import pyodbc
from datetime import datetime
from twikit import Client, TooManyRequests


# Credentials
USERNAME = 'williamms94'
PASSWORD = 'Fifehanmi100.@'

# Initialize client
client = Client('en-US')

# Search query for Web3
WEB3_TOPICS = [
    "DeFi", "NFTs", "DAOs", "Metaverse", "Layer 2", "Gaming", 
    "Bridges", "P2E", "Wallets", "Staking", "Liquidity", 
    "Airdrops", "Stablecoins", "Assets", "Guilds", "Shilling", 
    "Farming", "SocialFi", "Tokenomics", "Interoperability"
]

# Combine topics into a single search query with "OR"
QUERY = ' OR '.join(WEB3_TOPICS)

# Delay between requests to avoid rate limits
DELAY_SECONDS = (2, 5)
RATE_LIMIT_DELAY = 900  # 15 minutes

CSV_FILENAME = 'web3_tweets.csv'  # Name of the CSV file
MINIMUM_TWEETS = 400  # Modify this to the desired number of tweets to scrape

# Get the last tweet count from the CSV file
def get_last_tweet_count(filename):
    if os.path.exists(filename):
        with open(filename, 'r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            rows = list(reader)
            if len(rows) > 1:  # Ensure there's at least one row of data
                return int(rows[-1][0])  # The last tweet count from the last row
    return 0


# Create a new CSV file or append to an existing one
def write_tweet_to_csv(filename, tweet_data):
    file_exists = os.path.exists(filename)
    
    with open(filename, 'a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        
        # If file doesn't exist, write the header
        if not file_exists:
            writer.writerow(['Tweet_count', 'Username', 'Text', 'Created_At', 'Retweets', 'Likes', 'Views'])
        
        # Write the tweet data
        writer.writerow(tweet_data)


# Define an async function to retrieve tweets with the term "Web3"
async def search_web3_tweets():
    await client.login(
        auth_info_1=USERNAME,
        password=PASSWORD
    )
    
    print(f"{datetime.now()} - Logged in successfully!")

    last_tweet_count = get_last_tweet_count(CSV_FILENAME)  # Get the last tweet count
    tweet_count = last_tweet_count
    tweets = None

    while tweet_count < last_tweet_count + MINIMUM_TWEETS:
        delay = random.uniform(*DELAY_SECONDS)
        print(f'{datetime.now()} - Sleeping for {delay:.2f} seconds...')
        await asyncio.sleep(delay)
        
        try:
            if tweets is None:
                print(f"{datetime.now()} - Searching for Web3 tweets...")
                tweets = await client.search_tweet(QUERY, product='Top')
            else:
                print(f"{datetime.now()} - Getting next batch of tweets...")
                tweets = await tweets.next()

        except TooManyRequests:
            print(f"{datetime.now()} - Rate limit hit. Sleeping for {RATE_LIMIT_DELAY // 60} minutes...")
            await asyncio.sleep(RATE_LIMIT_DELAY)
            continue
        
        if not tweets:
            print(f"{datetime.now()} - No more tweets found.")
            break
        
        # Loop through the retrieved tweets and store the data
        for tweet in tweets:
            if any(keyword.lower() in tweet.text.lower() for keyword in WEB3_TOPICS):
                tweet_count += 1
                tweet_data = [
                    tweet_count,
                    tweet.user.name,
                    tweet.text,
                    tweet.created_at,
                    tweet.retweet_count,
                    tweet.favorite_count,
                    tweet.view_count if hasattr(tweet, 'view_count') else 'N/A'
                ]
                
                # Write the tweet data to CSV
                write_tweet_to_csv(CSV_FILENAME, tweet_data)
                
                # Output the tweet data to the console for feedback
                print(f"Tweet #{tweet_count}: {tweet_data}")

        if tweet_count >= last_tweet_count + MINIMUM_TWEETS:
            break

    print(f"{datetime.now()} - Done! Retrieved {tweet_count - last_tweet_count} new tweets.")

# Run the async function
asyncio.run(search_web3_tweets())
